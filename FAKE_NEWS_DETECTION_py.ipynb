# %% [markdown]
# # 1: Importing Modules

# %%
import pandas as pd      # For data handling
import numpy as np       # For numerical operations
from sklearn.linear_model import LogisticRegression   # The classifier
from sklearn.model_selection import train_test_split  # For splitting data
from sklearn.feature_extraction.text import TfidfVectorizer  # For converting text to numbers
from sklearn.metrics import accuracy_score, classification_report  # For evaluating the model
import joblib
from flask import Flask, request, jsonify

# %% [markdown]
# # 2:  Data Collection

# %%
Fake_data = pd.read_csv("Fake.csv",on_bad_lines="skip", engine='python')
True_data = pd.read_csv("True.csv",on_bad_lines="skip", engine='python')
df = pd.read_csv("fake_or_real_news.csv")
Fake_data["label"] = 0
True_data["label"] = 1
df["label"] = df["label"].apply(lambda x: 1 if x == "REAL" else 0)

# %% [markdown]
# # 3: Droping Unnecessary Columns

# %%
# Drop unused columns if present
Fake_data.drop(["title", "subject", "date"], axis=1, inplace=True, errors='ignore')
True_data.drop(["title", "subject", "date"], axis=1, inplace=True, errors='ignore')
df.drop(["title", "id"], axis=1, inplace=True, errors='ignore')

# %% [markdown]
# # 4: Convert text to lowercase

# %%
Fake_data["text"] = Fake_data["text"].str.lower()
True_data["text"] = True_data["text"].str.lower()
df["text"] = df["text"].str.lower()

# %% [markdown]
# # 5: Combining All 3 datasets

# %%
Combined_dataset = pd.concat([Fake_data, True_data, df])
Combined_dataset = Combined_dataset.sample(frac=1).reset_index(drop=True)

# %%
Combined_dataset.head(50)
# Out:
#                                                  text  label
# 0   a uniformed police officer in virginia said he...      0
# 1                                                          0
# 2   tallinn (reuters) - the european union should ...      1
# 3   21st century wire says russia hack? still no e...      0
# 4   bush spoke to a hispanic audience in central f...      0
# 5   rush limbaugh nails it in the transcript below...      0
# 6   youtube celebrity adam saleh has accused delta...      0
# 7   you re gonna love this patriot! he speaks for ...      0
# 8   san francisco (reuters) - a federal appeals co...      1
# 9   new york (reuters) - new york’s top democratic...      1
# 10  the chances of donald trump becoming the repub...      1
# 11  the anti-trump thugs are out in full force tod...      0
# 12  the producers vs. the looters the man honeymoo...      0
# 13  juba (reuters) - a south sudanese rebel group ...      1
# 14  behind the headlines - conspiracies, cover-ups...      0
# 15  beijing - china will expand a pilot project fo...      1
# 16  this copy of the antifa manual, that is used b...      0
# 17  zam zam camp, north darfur (reuters) - washing...      1
# 18  new york (reuters) - within minutes of jeb bus...      1
# 19  tirana (reuters) - the united states urged its...      1
# 20  many see a double standard in the fbi's recomm...      1
# 21  moscow (reuters) - russia has demanded an emer...      1
# 22  washington (reuters) - the u.s. small business...      1
# 23  beirut (reuters) - israeli missiles struck a m...      1
# 24  maputo (reuters) - gun battles last week betwe...      1
# 25  well, folks, your health care is safe for the ...      0
# 26  abdul razak ali artan, a somalian refugee came...      0
# 27  remember the fabled pee pee tapes? well, it se...      0
# 28  a black woman went into a fit of rage after sh...      0
# 29  more and more dirt on these two grifters who r...      0
# 30  how much longer before cops stop coming into t...      0
# 31  donald trump is making a key speech on the eco...      0
# 32  breaking: #timkaine rally only about 30 people...      0
# 33  washington (reuters) - the environmental prote...      1
# 34  the head of the epa under president barack oba...      0
# 35  washington (reuters) - the u.s. policy of tryi...      1
# 36  istanbul (reuters) - a turkish court on wednes...      1
# 37  republicans don t care about the american peop...      0
# 38  washington (reuters) - u.s. defense secretary ...      1
# 39  warsaw (reuters) - plans to overhaul poland s ...      1
# 40  florence, italy (reuters) - british prime mini...      1
# 41  washington (reuters) - u.s. president donald t...      1
# 42  washington (reuters) - the u.s. senate voted m...      1
# 43  washington (reuters) - donald trump on thursda...      1
# 44  if you were to believe barack hussein obama, h...      0
# 45  barack obama’s signature, as a speaker, is his...      1
# 46  just two weeks after republicans officially na...      0
# 47  when the news broke that our french colleagues...      1
# 48  donald trump: with fifty people dead and perha...      0
# 49  with a battle heating up between republicans a...      0

# %% [markdown]
# # 6: Checking Result

# %%
Combined_dataset.head()
Combined_dataset['label'].value_counts()
# Out:
# label
# 0    26645
# 1    24588
# Name: count, dtype: int64

# %% [markdown]
# # 7: Training And Evaluting Model

# %%
X_train,X_test,Y_train,Y_test = train_test_split(Combined_dataset["text"],Combined_dataset["label"],test_size = 0.2,random_state=42)

# %%
# A different approach to TF-IDF vectorization
# We can try different parameters for TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english', max_df=0.7,ngram_range=(1,2))

tfidf_train = tfidf.fit_transform(X_train)
tfidf_test = tfidf.transform(X_test)

# %%
model = LogisticRegression(class_weight="balanced")
model.fit(tfidf_train,Y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = model.predict(tfidf_test)
print("Accuracy : ", accuracy_score(Y_test,y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy :  0.9635015126378452
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      5354
#            1       0.96      0.96      0.96      4893
#
#     accuracy                           0.96     10247
#    macro avg       0.96      0.96      0.96     10247
# weighted avg       0.96      0.96      0.96     10247

# %%
sample = ["TOKYO (Reuters) - Japan's economy grew at an annualized rate of 0.5 percent in the third quarter, revised data showed on Monday, a sharp slowdown from the previous quarter's growth and weaker than a preliminary estimate."]
sample_tfidf = tfidf.transform(sample)
prediction = model.predict(sample_tfidf)
print("Fake" if prediction[0] == 0 else "Real")
# Out:
# Real

# %%
# Save the trained model and vectorizer
joblib.dump(model, 'model.pkl')
joblib.dump(tfidf, 'tfidf.pkl')
# Out:
# ['tfidf.pkl']
